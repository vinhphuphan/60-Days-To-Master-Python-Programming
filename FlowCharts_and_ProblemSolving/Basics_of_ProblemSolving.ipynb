# %% [markdown]
# #### 🧠 **1. Problem Solving (Giải quyết vấn đề) trong lập trình**
#
# ##### 📌 Là gì?
# Problem solving là quá trình **hiểu một bài toán, lên kế hoạch giải, và viết code để giải quyết**.
#
# ---
#
# #### 🧩 **Các bước cơ bản:**
#
# 1. **Hiểu đề**
#    - Đọc kỹ yêu cầu, dữ liệu đầu vào và đầu ra
#
# 2. **Phân tích bài toán**
#    - Xác định **input**, **output**, và các bước xử lý
#
# 3. **Lên kế hoạch giải (algorithm)**
#    - Có thể dùng giấy, vẽ flowchart, hoặc giả mã (pseudo-code)
#
# 4. **Viết code**
#
# 5. **Kiểm tra và sửa lỗi (debug/test)**
#
# 6. **Tối ưu nếu cần**
#
# ---
#
# #### 🔁 **2. Flowchart (Sơ đồ luồng)**
#
# ##### 📌 Là gì?
# Flowchart là **sơ đồ hình vẽ thể hiện các bước xử lý trong thuật toán**, giúp hình dung chương trình rõ ràng.
#
# ---
#
# ##### 🧱 **Các khối thường dùng:**
#
# | Hình | Ý nghĩa              |
# |------|----------------------|
# | ⬛   | **Start / End**       |
# | 🔲   | **Process (xử lý)**   |
# | 🔷   | **Decision (rẽ nhánh)** |
# | 🟦   | **Input/Output**      |
# | ➡️   | **Arrow** (chỉ luồng)  |
#
# ---
#
# ##### ✅ **Ví dụ: Giải bài toán kiểm tra số chẵn/lẻ**
#
# ###### 📄 Pseudo-code:
# ```
# Nhập số n
# Nếu n % 2 == 0:
#     In "Chẵn"
# Ngược lại:
#     In "Lẻ"
# ```
#
# ##### 📊 Flowchart:
#
# ```
# 🔲 Start
# ⬇️
# 🟦 Nhập n
# ⬇️
# 🔷 n % 2 == 0?
#  ↙️         ↘️
# 🔲 In "Chẵn"   🔲 In "Lẻ"
#   ↘️           ↘️
#      🔲 End
# ```
#
# ---
#
# #### ✅ Tóm tắt dễ nhớ:
# > **Problem solving** = Hiểu đề + Lên kế hoạch + Code
# > **Flowchart** = Cách vẽ **bức tranh trực quan** cho giải pháp
